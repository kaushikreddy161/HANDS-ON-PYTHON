# %% [markdown]
# <h3>1.ARITHMETIC OPERATOR </h3>

# %% [markdown]
# <h5>a.Define arithmetic operator. </h5>

# %% [markdown]
# </h5>performs mathematical operations on values such as addition ,subtarction,multiplication..etc</h5>

# %% [markdown]
# <h5>b.Create a Python script that defines two variables, num1 and num2, with any numeric values. Use arithmetic operators
# (+, -, *, /, //, %, **) to perform the following operations:
# <h5>Add num1 and num2.</h5>
#
# <h5>Subtract num2 from num1.</h5>
# <h5>Multiply num1 and num2.</h5>
# <h5>Divide num1 by num2.</h5>
# <h5>Find the floor division of num1 by num2.</h5>
# <h5>Find the remainder when dividing num1 by num2.</h5>
# <h5>Calculate num1 raised to the power of num2.</h5>

# %%
num1=10;
num2=3;
print("addition",num1+num2)
print("subtraction",num1-num2)
print("multiplication",num1*num2)
print("division",num1/num2)
print("floor division --removes decimal ",num1//num2)
print("remainder",num1%num2)
print("power",num1**num2)
# Out:
# addition 13
# subtraction 7
# multiplication 30
# division 3.3333333333333335
# floor division --removes decimal  3
# remainder 1
# power 1000

# %% [markdown]
# <h3>2.LOGICAL OPERATORS</h3>

# %% [markdown]
# <h5>a.Define Comparative Operator.</h5>

# %% [markdown]
# </h5>logical operators are a combination of multiple logic conditions which can return a boolean value  true or false.
# ex: AND,OR,NOT...</h5>

# %% [markdown]
# <h5>b.Create a Python script that defines two Boolean variables, is_sunny and is_warm, with appropriate values (True or False).
# Use logical operators (and, or, not) to create the following conditions:</h5>
# <h5>1.Check if it's both sunny and warm and print the result.</h5>
# <h5>2.Check if it's either sunny or warm and print the result.</h5>
# <h5>3.Check if it's not sunny and print the result.</h5>

# %% [markdown]
# <h5>a.Define Logical Operator:</h5>

# %%
is_sunny='true'
is_warm='false'
#both sunny and the warm
print("Both sunny and warm:",is_sunny and is_warm)
print("either sunny or warm:",is_sunny or is_warm)
print("not sunny :",not is_sunny )
# Out:
# Both sunny and warm: false
# either sunny or warm: true
# not sunny : False

# %% [markdown]
# <h3>3. COMPARATIVE OPERATORS:</h3>

# %% [markdown]
# <h5>a.Define Comparative Operator. </h5

# %% [markdown]
# </h5>Comparative (Relational) operators are used to compare two values and return True or False.</h5>

# %% [markdown]
# <h5>b.Create a Python script that defines two variables, a and b, with any numeric values.
# Use comparative operators (==, !=, <, >, <=, >=) to create the following conditions</h5>
# <h5>1.Check if a is equal to b and print the result.</h5>
# <h5>2.Check if a is not equal to b and print the result.</h5>
# <h5>3.Check if a is less than b and print the result.</h5>
# <h5>4.Check if a is greater than b and print the result.</h5>
# <h5>5.Check if a is less than or equal to b and print the result.</h5>
# <h5>6.Check if a is greater than or equal to b and print the result.</h5>

# %%
a=10;
b=20;
print("a == b is",a==b);
print("a!=b   is",a!=b);
print("a<b   is",a<b);
print("a>b   is",a>b);
print("a<=b   is",a<=b);
print("a>=b   is",a>=b);
# Out:
# a == b is False
# a!=b   is True
# a<b   is True
# a>b   is False
# a<=b   is True
# a>=b   is False

# %% [markdown]
# <h3>4. Identity Operators:</h3>

# %%
a=10;
b=10;
print(a is b)
print(a is not b)
# Out:
# True
# False

# %%
List1=[1,2,3]
list2=[1,2,3]
print(list1 is list2)
# flase because even both list has same values is compares memory locations(identity) not values
# Out:
# False

# %% [markdown]
# <h3> is operator compares memory locations(identity) </h3>
# ex:[1,2,3] is [1,2,3] → False
# is	Checks memory location
# <h3> == operator comapres values of them</h3>
# [1,2,3] == [1,2,3] → True

# %% [markdown]
# <h3>5. Assignment Operators:</h3>
# #assigning a value to the variable and perform operations
# <h3>What will be the value of x after the following operations?</h3>
# <h5>x = 5</h5> #5
# <h5>x += 3</h5>#8
# <h5>x -= 2</h5>#6

# %%
x = 5
print(x)
#prints 5
x += 3
print(x)
#prints 8
x -= 2
print(x)
#prints 6
# Out:
# 5
# 8
# 6

# %% [markdown]
# <h3>6. Membership Operators:</h3>
# #used to test if a value or variable is part of a sequence ex:in a list or tuple..etc

# %% [markdown]
# <h5>What will be the result of the following expression?</h5>
# <h5><h5>lst = [10, 20, 30, 40]</h5>
# <h5>print(30 in lst)</h5>
# <h5>print(50 not in lst)</h5>

# %%
lst = [10, 20, 30, 40]
print(30 in lst)
print(50 not in lst)
# Out:
# True
# True

# %% [markdown]
# <h4>How does the not in operator work in Python? Provide an example with a string.</h4>

# %%
NAME="kaushikreddy"
print("k" not in NAME)
print("z" not in NAME)
#not in prints true if element not present
# Out:
# False
# True
