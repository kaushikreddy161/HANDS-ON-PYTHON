# %%
# Task 1 - Identifiers

# Valid Identifiers
my_variable = 25
counter = 40.7
_total = "Hello"
Name123 = 136
myFunction = True
_data = False

print("Valid Identifiers Executed Successfully")
# Out:
# Valid Identifiers Executed Successfully

# %%
# Invalid Identifiers (Uncomment to test errors one by one)

# 123abc = 34          # Error: cannot start with number
# my variable = 6.7    # Error: space not allowed
# @count = "hi"        # Error: special character not allowed
# for = "True"         # Error: keyword
# if_condition? = "Innomatics"  # Error: special character '?'
# class = "Hyderabad"  # Error: keyword

# %%
# Task 2 - Assign Values

# Integers
num1 = 10
num2 = -5
num3 = 1000

# Floats
pi_value = 3.14159
negative_float = -0.12345

# Strings
INTRO = "Hello, World!"
CODE = "Python"
learning = "I am learning"
text_type = "Text type"
string_value = "String"

# Boolean
is_true = True
is_false = False

# Display all values
print("\nAssigned Values:")
print(num1, num2, num3)
print(pi_value, negative_float)
print(INTRO)
print(CODE)
print(learning)
print(text_type)
print(string_value)
print(is_true, is_false)
# Out:
# Assigned Values:
# 10 -5 1000
# 3.14159 -0.12345
# Hello, World!
# Python
# I am learning
# Text type
# String
# True False
